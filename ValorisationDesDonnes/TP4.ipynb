# %% [markdown]
# # TP4: Estimateurs ponctuels

# %%
M=1000
n=1000
x = matrix(rexp(M*n,1/3),n,M)
x.muhat = apply(x,2,mean)
f_mu = density(x.muhat)
plot(f_mu)
# Out:
# Plot with title "density.default(x = x.muhat)"
