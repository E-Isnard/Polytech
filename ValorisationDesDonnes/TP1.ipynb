# %% [markdown]
# # TP1: Valorisation des données

# %%
#Data
data <- c(23,24,24,25,24,24,24,25,26,22,21)
#Center/Location
mean(data) # Calcule la moyenne
median(data) #Calcule la médiane
#Dispersion
sd(data) # Calcule l'écart-type
var(data)# Calcule la variance
IQR(data) # Calcule l'écart interquartile(Q3-Q1)
#Rank
min(data) # Calcule le minimum
max(data) # Calcule le maximum
quantile(data,1/4) # Calcule le 25% quantile
# Out:
# [1] 23.81818
# [1] 24
# [1] 1.401298
# [1] 1.963636
# [1] 1
# [1] 21
# [1] 26
#  25%
# 23.5

# %%
n=30
k=1000
mu=5;sigma=2;sdclt=sigma/sqrt(n)
x = matrix(rnorm(n*k,mu,sigma),n,k) # Crée une matrice n*k valeurs d'une loi normale de paramètre (mu,sigma) 
#et les met dans une matrice
x.mean = apply(x,2,mean) # crée une vecteur des moyenne des colonnes
x.down = mu-4*sdclt;x.up=mu+4*sdclt;y.up=3/2
hist(x.mean,prob=T,xlim=c(x.down,x.up),ylim=c(0,y.up),main='Sampling distribution of the sample mean,Normal) case')

par(new=T)
x = seq(x.down,x.up,0.01)
y=dnorm(x,mu,sdclt)
plot(x,y,type='l',xlim=c(x.down,x.up),ylim=c(0,y.up))
# Out:
# Plot with title "Sampling distribution of the sample mean,Normal) case"

# %%
data(iris)
dim(iris)
class(iris)
summary(iris)
head(iris)
sapply(iris,class)
plot(iris$Sepal.Length)
plot(iris$Sepal.Length, iris$Sepal.Width)
library(RColorBrewer)
display.brewer.all(n=3)
plot(Sepal.Width ~ Sepal.Length,data=iris,col=brewer.pal(3,"Set2")[iris$Species])
legend(x=6.5,y=4.5,legend=levels(iris$Species),col=brewer.pal(3,"Set2"),pch=1)
x <- hist(iris$Sepal.Length)
segments(x0=x$mids-1/4,x1=x$mids+1/4,y0=x$counts,y1=x$counts,lw=4,col="red")
#Iris is a dataset
# Out:
# [1] 150   5
# [1] "data.frame"
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300
#  Mean   :5.843   Mean   :3.057   Mean   :3.758   Mean   :1.199
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500
#        Species
#  setosa    :50
#  versicolor:50
#  virginica :50
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa
# ...

# %%
flights <- read.csv("2008.csv")

# %%
summary(flights)
# Out:
# Error in summary(flights): objet 'flights' introuvable
# Traceback:
#
# 1. summary(flights)

# %%
dim(flights)
ncol(flights)
names(flights)
class(which(is.na(flights),1))
length(which(is.na(flights)))
length(which(is.na(flights)))/(ncol(flights)*nrow(flights))
# Out:
# [1] 7009728      29
# [1] 29
#  [1] "Year"              "Month"             "DayofMonth"
#  [4] "DayOfWeek"         "DepTime"           "CRSDepTime"
#  [7] "ArrTime"           "CRSArrTime"        "UniqueCarrier"
# [10] "FlightNum"         "TailNum"           "ActualElapsedTime"
# [13] "CRSElapsedTime"    "AirTime"           "ArrDelay"
# [16] "DepDelay"          "Origin"            "Dest"
# [19] "Distance"          "TaxiIn"            "TaxiOut"
# [22] "Cancelled"         "CancellationCode"  "Diverted"
# [25] "CarrierDelay"      "WeatherDelay"      "NASDelay"
# [28] "SecurityDelay"     "LateAircraftDelay"
# [1] "matrix" "array"
# [1] 28602754
# [1] 0.1407047
