# %% [markdown]
# # Optimisation Bayesienne

# %% [markdown]
# #### 1. Généralisation de réalisations de processus stochastique 1D

# %%
# Importation des librairies nécessaires

import numpy as np
import numpy.linalg as LA
from numpy.random import multivariate_normal
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy.linalg import sqrtm
from scipy.optimize import minimize
from scipy.stats import norm
from pyDOE import lhs
import cma
import pyswarm
import sys
import os
from ipywidgets import interact, interactive, fixed, interact_manual,widgets

# %%
# Fonctions de covariances de processus gaussiens
# Le décorateur @np.vectorize sert à ce qu'on puisse utiliser les fonctions sur des vecteurs

@np.vectorize
def kg(x1,x2,theta=0.2,sigma=1):
    """
    Noyau de covariance gaussien
    """
    return sigma**2*np.exp(-(LA.norm(x1-x2)/theta)**2)

@np.vectorize
def ke(x1,x2,theta=0.2,sigma=1):
    """
    Noyau de covariance exponentiel
    """
    return sigma**2*np.exp(-LA.norm(x1-x2)/theta)

@np.vectorize
def kb(x1,x2):
    """
    Noyau de covariance d'un mouvement brownien (ne fonctionne qu'en 1D)
    """
    return min(x1,x2)

# %%
x1 = np.linspace(-1,1,200)
x2 = 0
theta=0.2
plt.title(f"Graphe des noyaux de covariance avec x2 fixé à {x2} et theta={theta}")
plt.plot(x1,kg(x1,x2,theta),label="Noyau gaussien")
plt.plot(x1,ke(x1,x2,theta),label="Noyau exponentiel")
plt.plot(x1,kb(x1,x2),label="Noyau brownien")
plt.legend()
plt.grid(ls="--")
plt.show()

# %%
np.random.seed(0)
def plot_gaussian_process(sigma,theta):
    n2=100
    x = np.linspace(0,1,n2)
    O = np.zeros((n2,))
    I = np.eye(n2,n2)
    Kg = np.array([[kg(xi,xj,theta,sigma) for xi in x] for xj in x])
    Ke = np.array([[ke(xi,xj,theta,sigma) for xi in x] for xj in x])
    Z = multivariate_normal(O,I)
    Yg = np.real(sqrtm(Kg))@Z
    Ye = np.real(sqrtm(Ke))@Z
    plt.title("Graphe de réalisations de processus gaussiens avec les noyaux gaussien et exponentiel")
    plt.plot(x,np.array([Yg,Ye]).T)
    plt.legend(["Noyau Gaussien","Noyau exponentiel"])
    plt.grid(ls="--")
    plt.show()

interact(plot_gaussian_process,theta=(0.05,0.50,0.05),sigma=(1,10))
plt.show()
# Out:
# interactive(children=(IntSlider(value=5, description='sigma', max=10, min=1), FloatSlider(value=0.25, descript…

# %% [markdown]
# $θ$ influe sur à quel point le processus varie et $σ$ influe sur l'amplitude des variations.

# %% [markdown]
# #### 2. Métamodélisation

# %%
def fb(x):
    """
    Fonction de Branin avec les variables normalisées
    """
    pi = np.pi
    x1,x2 = x
    x1 = 15*x1-5
    x2 = 15*x2
    return (x2-5.1/(4*pi**2)*x1**2+5/pi*x1-6)**2+10*((1-1/(8*pi))*np.cos(x1)+1)+5*x1

N=51
x1 = np.linspace(0,1,N)
x2 = np.linspace(0,1,N)

def eval_func(x1,x2,f):
    X1,X2 = np.meshgrid(x1,x2)
    Z = np.zeros(X1.shape)
    for i,xi in enumerate(x1):
        for j,xj in enumerate(x2):
            Z[i,j]=f([xi,xj])
    return X1,X2,Z
X1,X2,Z = eval_func(x1,x2,fb)
plt.title("Plot de la fonction de Branin")
plt.imshow(Z,cmap=cm.jet,origin="lower")
plt.show()
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.set_title("Plot 3D de la fonction de Branin")
ax.plot_surface(X1,X2,Z,cmap=cm.jet)
plt.show()

# %% [markdown]
# On définit les fonctions pour le krigeage:
#
# Elle résolvent le système $K_nλ =k_n$ et donnent comme résultat de l'interpolation $m_n = \sum_i λ_i y_i = λ^Ty$

# %%
if type(kg)==type(np.vectorize(lambda x:x)):
    kg = kg.pyfunc

def r(X1,X2,k_func=kg):
    if type(X1)==list:
        X1 = np.array(X1).reshape(1,-1)
    if type(X2)==list:
        X2 = np.array(X2).reshape(1,-1)
    R = np.zeros((X1.shape[0],X2.shape[0]))
    for i,xi in enumerate(X1):
        for j,xj in enumerate(X2):
            R[i,j] = k_func(xi,xj)
    return R

def y_func(X):
    y = np.zeros((len(X),1))
    for i,xi in enumerate(X):
        y[i] = fb(xi)
    return y

def mn(x,X,k_func=kg):
    r_vec = r(x,X,k_func)
    R_mat = r(X,X,k_func)
    y = y_func(X)
    return r_vec@(np.linalg.solve(R_mat,y))

def sigman2(Xn,k_func=kg):
    y = y_func(Xn)
    R_mat = r(Xn,Xn,k_func)
    n = R_mat.shape[0]
    return 1/n*y.T@(LA.solve(R_mat,y))

def vn(x,X,k_func=kg):
    r_vec = r(x,X,k_func=k_func).T
    sigma2 = sigman2(X,k_func=k_func)
    Rn = r(X,X,k_func=k_func)
    c = np.sum(r_vec*(LA.solve(Rn,r_vec)),axis=0)
    return sigma2*(1-c)

# %%
x_uni = np.linspace(0,1,num=3)
X_uni = np.array([[xi,xj] for xi in x_uni for xj in x_uni])
plt.figure(figsize=(6,6))
plt.scatter(X_uni[:,0],X_uni[:,1])
plt.title("Design uniforme")
plt.show()
n_test = 50
x_test = np.linspace(0,1,n_test)
X_test = np.array([[xi,xj] for xi in x_test for xj in x_test])
_,_,Z_true = eval_func(x_test,x_test,lambda x: fb(x))
Z = mn(X_test,X_uni).reshape(n_test,n_test)
S = vn(X_test,X_uni).reshape(n_test,n_test)
fig,(ax1,ax2,ax3) = plt.subplots(1,3)
fig.set_size_inches(20, 20)
pl1 = ax1.imshow(Z_true,cmap=cm.jet,origin="lower")
plt.colorbar(pl1,ax=ax1,shrink=0.3)
ax1.set_title("True values")
pl2 = ax2.imshow(Z,cmap=cm.jet,origin="lower")
plt.colorbar(pl2,ax=ax2,shrink=0.3)
ax2.set_title("Simple kriging")
pl3 = ax3.imshow(S,cmap=cm.jet,origin="lower")
plt.colorbar(pl3,ax=ax3,shrink=0.3)
ax3.set_title("Variance of the meta-model")
plt.show()


print(f"Erreur en norme L2 entre Z_true et Z: {LA.norm(Z_true-Z)}")
# Out:
# Erreur en norme L2 entre Z_true et Z: 2445.6777374992

# %%
X_lhs = lhs(2,9,criterion="maximin",iterations=100)
plt.figure(figsize=(6,6))
plt.scatter(X_lhs[:,0],X_lhs[:,1])
plt.title("LHS avec critère maximin optimisé")
plt.show()

n_test = 50
x_test = np.linspace(0,1,n_test)
X_test = np.array([[xi,xj] for xi in x_test for xj in x_test])
_,_,Z_true = eval_func(x_test,x_test,lambda x: fb(x))
Z = mn(X_test,X_lhs).reshape(n_test,n_test)
S = vn(X_test,X_lhs).reshape(n_test,n_test)
fig,(ax1,ax2,ax3) = plt.subplots(1,3)
fig.set_size_inches(20, 20)
pl1 = ax1.imshow(Z_true,cmap=cm.jet,origin="lower")
plt.colorbar(pl1,ax=ax1,shrink=0.3)
ax1.set_title("True values")
pl2 = ax2.imshow(Z,cmap=cm.jet,origin="lower")
plt.colorbar(pl2,ax=ax2,shrink=0.3)
ax2.set_title("Simple kriging")
pl3 = ax3.imshow(S,cmap=cm.jet,origin="lower")
plt.colorbar(pl3,ax=ax3,shrink=0.3)
ax3.set_title("Variance of the meta-model")
plt.show()


print(f"Erreur en norme L2 entre Z_true et Z: {LA.norm(Z_true-Z)}")
# Out:
# Erreur en norme L2 entre Z_true et Z: 1937.584075972752

# %% [markdown]
# On a une erreur un peu moins grande avec le LHS qu'avec la grille uniforme.

# %%
@np.vectorize
def ll(theta,X=X_lhs):
    """
    Fonction de log-vraissemblance log-L(θ|X)
    """
    n = len(X)
    sn = sigman2(X_lhs,lambda x1,x2: kg(x1,x2,theta=theta))
    Rn = r(X_lhs,X_lhs,lambda x1,x2: kg(x1,x2,theta=theta))
    return (-n/2*np.log(2*np.pi)-n/2*np.log(sn)-1/2*np.log(LA.det(Rn))-n/2)[0][0]
theta = np.linspace(0.2,1)

#On utilise BFGS (methode de gradient) parce que la fonction est concave que c'est ce qui a de plus efficace dans ce cas.
theta_opt = minimize(lambda t: -ll(t),0.2,method="BFGS").x
print(f"θ_opt = {theta_opt[0]}")
plt.plot(theta,ll(theta))
plt.plot(theta_opt,ll(theta_opt),"rx",label="$\\theta_{opt}$")
plt.title("Graphe de la fonction de log-vraissemblance")
plt.xlabel("$\\theta$")
plt.ylabel("$\log\mathcal{L}(\\theta|X)$")
plt.grid(ls="--")
plt.legend()
plt.show()
# Out:
# θ_opt = 0.534902210495897

# %% [markdown]
# #### 3. EGO

# %%
def EI(x,X):
    """
    Fonction d'amélioration espérée (Expected improvement)
    E[max(fmin-Y,0)]
    """
    y = y_func(X)
    ymin = np.min(y)
    mx = mn(x,X)
    sn = np.sqrt(vn(x,X)).T
    return (ymin-mx)*norm.cdf((ymin-mx)/sn)+sn*norm.pdf((ymin-mx)/sn)

# %%
pl = plt.imshow(EI(X_test,X_lhs).reshape(n_test,n_test),cmap=cm.jet,origin="lower")
plt.title("Amélioration espérée")
plt.xlabel("X")
plt.ylabel("Y")
plt.colorbar(pl)
plt.show()

# %% [markdown]
# On utilise CMA-ES car c'est un bon algorithme d'optimisation globale

# %%
from feuDeForet import muLambda
def EGO_one_step(X):
    # penalization function
    p = lambda x: 100*(x[0]<0 or x[0]>1 or x[1]<0 or x[1]>1)
    J = lambda x: p(x)-EI(x,X)[0][0]
    x = cma.fmin(J,[1/2,1/2],1/4)[0]
    # x = muLambda(J,[1/2,1/2],0.25,2,10,0.1,nmax=5).best
    return x

def EGO_n_steps(X,n=1):
    X_c = np.copy(X)
    for i in range(n):
        x = EGO_one_step(X_c)
        X_c = np.vstack([X_c,x])
    return X_c,x
X2,x_opt = EGO_n_steps(X_lhs,1)
print(f"{x_opt = }")
plt.scatter(X2[:,0],X2[:,1])
plt.title("New DOE")
plt.show()
# Out:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-8:
# Traceback (most recent call last):
# Process ForkPoolWorker-2:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/queues.py", line 356, in get
#     res = self._reader.recv_bytes()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/enzo/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_55376/1337123057.py in <module>
# ----> 1 from feuDeForet import muLambda
#       2 def EGO_one_step(X):
#       3     # penalization function
#       4     p = lambda x: 100*(x[0]<0 or x[0]>1 or x[1]<0 or x[1]>1)
#       5     J = lambda x: p(x)-EI(x,X)[0][0]
#
# ~/Documents/Polytech/ConceptionOptimale/feuDeForet.py in <module>
#     370 # C,T = simu(*x0)
#     371 # anim2d(C,T)
# --> 372 res = Torczon(J2,x0,eps=1e-4,disp=1,nmax=50,hist=True)
#     373 res2 = muLambda(J2, x0, sigma0, mu2, lamb, tau, eps=1e-4,
#     374                disp=1,hist=True, nmax=50, version="comma")
#
# ~/Documents/Polytech/ConceptionOptimale/feuDeForet.py in Torczon(f, x0, step, alpha, gamma, beta, eps, nmax, disp, hist)
#     255     x[0] = x0
#     256     x[1:] = x0+np.eye(dim, dim)*step
# --> 257     fx = parallel_apply_along_axis(f,1,x)
#     258     n_eval += len(x)
#     259     sort = np.argsort(fx)
#
# ~/Documents/Polytech/ConceptionOptimale/feuDeForet.py in parallel_apply_along_axis(func1d, axis, arr, *args, **kwargs)
#      39
#      40     pool = multiprocessing.Pool()
# ---> 41     individual_results = pool.map(unpacking_apply_along_axis, chunks)
#      42     # Freeing the workers:
#      43     pool.close()
#
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
Z = mn(X_test,X_lhs).reshape(n_test,n_test)
plt.imshow(Z,cmap=cm.jet,origin="lower")
